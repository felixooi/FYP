# %%
# Install pytest
# !pip install pytest pytest-cov

# %%
# !pip install imbalanced-learn scikit-learn pandas numpy matplotlib seaborn

# %%
# Or run specific module
# !pytest tests/test_imbalance_handling.py -v
# Out:
# ]9;4;3;\============================= test session starts ==============================
# platform linux -- Python 3.10.19, pytest-9.0.1, pluggy-1.6.0 -- /home/ec2-user/anaconda3/envs/pytorch_p310/bin/python3.10
# cachedir: .pytest_cache
# rootdir: /home/ec2-user/SageMaker
# plugins: anyio-4.11.0, cov-7.0.0
# collected 6 items
#
# tests/test_imbalance_handling.py::TestAnalyzeImbalance::test_returns_ratio ]9;4;1;0\PASSED [ 16%]
# tests/test_imbalance_handling.py::TestHandleImbalance::test_smote_increases_minority ]9;4;1;16\PASSED [ 33%]
# tests/test_imbalance_handling.py::TestHandleImbalance::test_adasyn_method ]9;4;1;33\PASSED [ 50%]
# tests/test_imbalance_handling.py::TestCompareResamplingMethods::test_returns_comparison_df ]9;4;1;50\PASSED [ 66%]
# tests/test_imbalance_handling.py::TestNegativeCases::test_missing_parameters ]9;4;1;66\PASSED [ 83%]
# tests/test_imbalance_handling.py::TestNegativeCases::test_single_class_only ]9;4;1;83\PASSED [100%]]9;4;0;\
#
# ...

# %%
# !pytest tests/test_data_transformation.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /home/ec2-user/anaconda3/bin/python3.12
# cachedir: .pytest_cache
# rootdir: /home/ec2-user/SageMaker
# plugins: anyio-4.11.0
# collected 11 items
#
# tests/test_data_transformation.py::TestApplyScaling::test_standard_scaler PASSED [  9%]
# tests/test_data_transformation.py::TestApplyScaling::test_minmax_scaler PASSED [ 18%]
# tests/test_data_transformation.py::TestApplyScaling::test_robust_scaler PASSED [ 27%]
# tests/test_data_transformation.py::TestApplyScaling::test_preserves_target PASSED [ 36%]
# tests/test_data_transformation.py::TestApplyScaling::test_invalid_method_fallback PASSED [ 45%]
# tests/test_data_transformation.py::TestApplyScaling::test_full_pipeline PASSED [ 54%]
# tests/test_data_transformation.py::TestAnalyzeTransformedCorrelations::test_returns_correlation_matrix PASSED [ 63%]
# ...

# %%
# !pytest tests/test_data_partition.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /home/ec2-user/anaconda3/bin/python3.12
# cachedir: .pytest_cache
# rootdir: /home/ec2-user/SageMaker
# plugins: anyio-4.11.0
# collected 9 items
#
# tests/test_data_partition.py::TestPartitionData::test_correct_split_sizes PASSED [ 11%]
# tests/test_data_partition.py::TestPartitionData::test_stratification_check PASSED [ 22%]
# tests/test_data_partition.py::TestPartitionData::test_no_data_loss PASSED [ 33%]
# tests/test_data_partition.py::TestGeneratePartitionReport::test_report_generation PASSED [ 44%]
# tests/test_data_partition.py::TestGeneratePartitionReport::test_report_structure PASSED [ 55%]
# tests/test_data_partition.py::TestCreateDataPartition::test_full_pipeline PASSED [ 66%]
# tests/test_data_partition.py::TestNegativeCases::test_invalid_split_sizes PASSED [ 77%]
# ...
